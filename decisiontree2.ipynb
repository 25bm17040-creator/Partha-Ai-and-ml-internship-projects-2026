# %% [markdown]
# <a href="https://colab.research.google.com/github/25bm17040-creator/Partha-Ai-and-ml-internship-projects-2026/blob/main/decisiontree2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

# %%
data = pd.read_csv("decisiontree2.csv")
x= data[["tempMode","AQ","USS","CS","VOC","RP","IP","Temperature"]]
y= data["fail"]

# %%
model= DecisionTreeClassifier(criterion='entropy')
model.fit(x,y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
sample=[[4,5,3,6,1,45,5,1]]

# %%
prediction=model.predict(sample)
print("Prediction: ",prediction)
# Out:
# Prediction:  [1]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
if prediction == 0:
  print("SYSTEM WILL FAIL")
else:
  print("SYSTEM WILL FAIL")
# Out:
# SYSTEM WILL FAIL

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
from sklearn import tree

plt.figure(figsize=(8,8))
tree.plot_tree(
    model,
    feature_names=x.columns.tolist(),
    class_names=['Pass', 'Fail'],
    filled=True)
plt.title("Decision Tree")
plt.show()
